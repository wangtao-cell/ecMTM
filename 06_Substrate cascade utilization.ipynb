# %%
import sys
import pandas as pd
import re
sys.path.append(r'./script/')
from ECMpy_function import *
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # input and output files

# %%
json_output_file = './model/ecMTM.json'
json_model_file=json_output_file
reaction_kcat_MW_outfile = './get_reaction_kcat/kcat/reaction_change_by_C13_TurNup24_1.csv'
reaction_kcat_MW = pd.read_csv(reaction_kcat_MW_outfile,index_col=0)
reaction_kcat_MW = round(reaction_kcat_MW,3)

# %%
enz_model=get_enzyme_constraint_model(json_model_file)
enz_model.reactions.get_by_id("R1975_num1").bounds=(0,0)
enz_model.reactions.get_by_id("R1975_num2").bounds=(0,0)
enz_model.reactions.get_by_id("R1975_num3").bounds=(0,0)
enz_model.reactions.get_by_id("R1975_num4").bounds=(0,0)
enz_model.reactions.get_by_id("R1975_num5").bounds=(0,0)
pfba_solution = cobra.flux_analysis.pfba(enz_model)
enz_solution=get_min_enzyme_cost(enz_model,reaction_kcat_MW)
min_enzyme_cost=enz_solution.objective_value
enzyme_efficiency= pfba_solution.fluxes['Biomass']/enz_solution.objective_value
print(min_enzyme_cost,enzyme_efficiency)
# Out:
# 0.128
# 0.12799999649527227 2.8589755528692744

# %% [markdown]
# # 不同碳源下biomass,以及酶利用效率

# %%
# obj='Biomass'
# substrate_list=[{'R2399_reverse':'D-Glucose'},{'R2402':'D-Fructose'},{'R2412':'Sucrose'},{}'R2417','R2411','R2401','R2408','R2405'] 

substrate_list=[{'R2399_reverse':'D-Glucose'},{'R2417':'Cellobiose'},{'R2401':'D-Galactose'},{'R2408':'D-Xylose'},{'R2406':'L-Arabinose'}] 
#substrate list 葡萄糖、果糖、蔗糖、纤维二糖、麦芽糖、半乳糖、木糖、阿拉伯糖

yield_list = pd.DataFrame()
for i in substrate_list:
#     print(list(i.keys())[0])
#     print(list(i.values())[0])

    enz_model=get_enzyme_constraint_model(json_model_file)
    enz_model.reactions.get_by_id("R2393").bounds=(0,0)
    enz_model.reactions.get_by_id("R2394").bounds=(-1000,1000)
    enz_model.reactions.get_by_id('R2399_reverse').bounds=(0,0)
    enz_model.reactions.get_by_id('R2399').bounds=(0,0)
    enz_model.reactions.get_by_id(list(i.keys())[0]).bounds=(-5,5)
    pfba_solution = cobra.flux_analysis.pfba(enz_model)
    enz_solution=get_min_enzyme_cost(enz_model,reaction_kcat_MW)
    min_enzyme_cost=enz_solution.objective_value
    enzyme_efficiency= pfba_solution.fluxes['Biomass']/enz_solution.objective_value
    print("糖的通量：",pfba_solution.fluxes[i])
    yield_list.loc[list(i.values())[0],'min_enzyme_cost']=min_enzyme_cost
    yield_list.loc[list(i.values())[0],'enzyme_efficiency']=enzyme_efficiency
    yield_list.loc[list(i.values())[0],'ecGEM_flux']=pfba_solution.fluxes['Biomass']
# Out:
# 0.128
# 糖的通量： R2399_reverse    5.0
# Name: fluxes, dtype: float64
# 0.128
# 糖的通量： R2417   -5.0
# Name: fluxes, dtype: float64
# 0.128
# 糖的通量： R2401   -4.310054
# Name: fluxes, dtype: float64
# 0.128
# 糖的通量： R2408   -4.822906
# Name: fluxes, dtype: float64
# 0.128
# 糖的通量： R2406   -3.819919
# Name: fluxes, dtype: float64

# %% [markdown]
# # 生物质前体

# %%
# 底物
substrate_list=[{'R2399_reverse':'D-Glucose'},{'R2417':'Cellobiose'},{'R2401':'D-Galactose'},{'R2408':'D-Xylose'},{'R2406':'L-Arabinose'}] 

#生物质前体list
min_enzyme = pd.DataFrame()
efficiency=pd.DataFrame()
bilist=['g6p_c','f6p_c','g3p_c','3pg_c','pep_c','pyr_c','accoa_m','oaa_m','akg_m','succ_m','e4p_c','R5P_c']
for index in substrate_list:
    for name in bilist:
        enz_model=get_enzyme_constraint_model(json_model_file)
        
        product = enz_model.metabolites.get_by_id(name)
        demand = enz_model.add_boundary(product, type='demand')  # add demand reaction as the objective 增加需求反应作为目标
        enz_model.objective = demand
        print('demand:',demand.id)
#       enz_model.reactions.get_by_id('Biomass').bounds=(0.03,0.03)#保证生物量能达到之前的百分之十
        
        #选择底物
        enz_model.reactions.get_by_id('R2399_reverse').bounds=(0,0)
        enz_model.reactions.get_by_id('R2399').bounds=(0,0)
        if list(index.keys())[0]=='R2417':#纤维二糖
            enz_model.reactions.get_by_id(list(index.keys())[0]).bounds=(-1.25,1.25)
        elif list(index.keys())[0]=='R2408' or list(index.keys())[0]=='R2406':#木糖
            enz_model.reactions.get_by_id(list(index.keys())[0]).bounds=(-3,3)
        else :
            enz_model.reactions.get_by_id(list(index.keys())[0]).bounds=(-2.5,2.5)
        #计算酶量以及效率
        print(index,name)
        pfba_solution = cobra.flux_analysis.pfba(enz_model)
        enz_solution=get_min_enzyme_cost(enz_model,reaction_kcat_MW)#获取最小酶量
        min_enzyme_cost=enz_solution.objective_value#最小酶量
        enzyme_efficiency= pfba_solution.fluxes[demand.id]/enz_solution.objective_value#酶利用效率
        min_enzyme.loc[list(index.values())[0],name.upper()]=min_enzyme_cost
        efficiency.loc[list(index.values())[0],name.upper()]=enzyme_efficiency
        fluxes_outfile='./analysis/'+list(index.values())[0]+name+'.csv'
        get_fluxes_detail_in_model(enz_model,enz_solution,fluxes_outfile,json_model_file)
# Out:
# 0.128
# demand: DM_g6p_c
# {'R2399_reverse': 'D-Glucose'} g6p_c
# Enzyme cost total is:0.026766671801793623
# 0.128
# demand: DM_f6p_c
# {'R2399_reverse': 'D-Glucose'} f6p_c
# Enzyme cost total is:0.025564966555273714
# 0.128
# demand: DM_g3p_c
# {'R2399_reverse': 'D-Glucose'} g3p_c
# Enzyme cost total is:0.03779497941496158
# 0.128
# demand: DM_3pg_c
# {'R2399_reverse': 'D-Glucose'} 3pg_c
# Enzyme cost total is:0.019647380316389653
# 0.128
# demand: DM_pep_c
# {'R2399_reverse': 'D-Glucose'} pep_c
# Enzyme cost total is:0.02252861009049719
# 0.128
# demand: DM_pyr_c
# {'R2399_reverse': 'D-Glucose'} pyr_c
# Enzyme cost total is:0.007915963331416701
# 0.128
# demand: DM_accoa_m
# {'R2399_reverse': 'D-Glucose'} accoa_m
# Enzyme cost total is:0.12799999999999956
# 0.128
# demand: DM_oaa_m
# {'R2399_reverse': 'D-Glucose'} oaa_m
# Enzyme cost total is:0.02332557360960845
# 0.128
# demand: DM_akg_m
# {'R2399_reverse': 'D-Glucose'} akg_m
# Enzyme cost total is:0.10586568181084526
# 0.128
# demand: DM_succ_m
# {'R2399_reverse': 'D-Glucose'} succ_m
# Enzyme cost total is:0.02712683529846581
# 0.128
# demand: DM_e4p_c
# {'R2399_reverse': 'D-Glucose'} e4p_c
# Enzyme cost total is:0.041487147094835565
# 0.128
# demand: DM_R5P_c
# {'R2399_reverse': 'D-Glucose'} R5P_c
# Enzyme cost total is:0.03576730403934018
# 0.128
# demand: DM_g6p_c
# {'R2417': 'Cellobiose'} g6p_c
# Enzyme cost total is:0.02227969181934451
# 0.128
# demand: DM_f6p_c
# {'R2417': 'Cellobiose'} f6p_c
# Enzyme cost total is:0.021770145734432637
# 0.128
# demand: DM_g3p_c
# {'R2417': 'Cellobiose'} g3p_c
# Enzyme cost total is:0.03418658967621907
# 0.128
# demand: DM_3pg_c
# {'R2417': 'Cellobiose'} 3pg_c
# Enzyme cost total is:0.01656967749344719
# 0.128
# demand: DM_pep_c
# {'R2417': 'Cellobiose'} pep_c
# Enzyme cost total is:0.019450907267554603
# 0.128
# demand: DM_pyr_c
# {'R2417': 'Cellobiose'} pyr_c
# Enzyme cost total is:0.008275577836425439
# 0.128
# demand: DM_accoa_m
# {'R2417': 'Cellobiose'} accoa_m
# Enzyme cost total is:0.1279999999999999
# 0.128
# demand: DM_oaa_m
# {'R2417': 'Cellobiose'} oaa_m
# Enzyme cost total is:0.023515831046867657
# 0.128
# demand: DM_akg_m
# {'R2417': 'Cellobiose'} akg_m
# Enzyme cost total is:0.10082581517770033
# 0.128
# demand: DM_succ_m
# {'R2417': 'Cellobiose'} succ_m
# Enzyme cost total is:0.027001881909958145
# 0.128
# demand: DM_e4p_c
# {'R2417': 'Cellobiose'} e4p_c
# Enzyme cost total is:0.037935039783899636
# 0.128
# demand: DM_R5P_c
# {'R2417': 'Cellobiose'} R5P_c
# Enzyme cost total is:0.032128004953341824
# 0.128
# demand: DM_g6p_c
# {'R2401': 'D-Galactose'} g6p_c
# Enzyme cost total is:0.03668593267322097
# 0.128
# demand: DM_f6p_c
# {'R2401': 'D-Galactose'} f6p_c
# Enzyme cost total is:0.036818917119338185
# 0.128
# demand: DM_g3p_c
# {'R2401': 'D-Galactose'} g3p_c
# Enzyme cost total is:0.04904892997902591
# 0.128
# demand: DM_3pg_c
# {'R2401': 'D-Galactose'} 3pg_c
# Enzyme cost total is:0.030901330880454145
# 0.128
# demand: DM_pep_c
# {'R2401': 'D-Galactose'} pep_c
# Enzyme cost total is:0.03378256065456154
# 0.128
# demand: DM_pyr_c
# {'R2401': 'D-Galactose'} pyr_c
# Enzyme cost total is:0.01916991389548104
# 0.128
# demand: DM_accoa_m
# {'R2401': 'D-Galactose'} accoa_m
# Enzyme cost total is:0.12799999999999984
# 0.128
# demand: DM_oaa_m
# {'R2401': 'D-Galactose'} oaa_m
# Enzyme cost total is:0.033647197202071905
# 0.128
# demand: DM_akg_m
# {'R2401': 'D-Galactose'} akg_m
# Enzyme cost total is:0.11711963237490942
# 0.128
# demand: DM_succ_m
# {'R2401': 'D-Galactose'} succ_m
# Enzyme cost total is:0.03833637213958024
# 0.128
# demand: DM_e4p_c
# {'R2401': 'D-Galactose'} e4p_c
# Enzyme cost total is:0.052741097658900074
# 0.128
# demand: DM_R5P_c
# {'R2401': 'D-Galactose'} R5P_c
# Enzyme cost total is:0.047021254603404415
# 0.128
# demand: DM_g6p_c
# {'R2408': 'D-Xylose'} g6p_c
# Enzyme cost total is:0.04556466445069237
# 0.128
# demand: DM_f6p_c
# {'R2408': 'D-Xylose'} f6p_c
# Enzyme cost total is:0.044192874987555815
# 0.128
# demand: DM_g3p_c
# {'R2408': 'D-Xylose'} g3p_c
# Enzyme cost total is:0.05390154079212807
# 0.128
# demand: DM_3pg_c
# {'R2408': 'D-Xylose'} 3pg_c
# Enzyme cost total is:0.035753941693556286
# 0.128
# demand: DM_pep_c
# {'R2408': 'D-Xylose'} pep_c
# Enzyme cost total is:0.03863517146766372
# 0.128
# demand: DM_pyr_c
# {'R2408': 'D-Xylose'} pyr_c
# Enzyme cost total is:0.0240225247085832
# 0.128
# demand: DM_accoa_m
# {'R2408': 'D-Xylose'} accoa_m
# Enzyme cost total is:0.128000000000001
# 0.128
# demand: DM_oaa_m
# {'R2408': 'D-Xylose'} oaa_m
# Enzyme cost total is:0.036845774166840935
# 0.128
# demand: DM_akg_m
# {'R2408': 'D-Xylose'} akg_m
# Enzyme cost total is:0.12197224318800987
# 0.128
# demand: DM_succ_m
# {'R2408': 'D-Xylose'} succ_m
# Enzyme cost total is:0.042530507171573084
# 0.128
# demand: DM_e4p_c
# {'R2408': 'D-Xylose'} e4p_c
# Enzyme cost total is:0.051955331855894404
# 0.128
# demand: DM_R5P_c
# {'R2408': 'D-Xylose'} R5P_c
# Enzyme cost total is:0.039953056260801145
# 0.128
# demand: DM_g6p_c
# {'R2406': 'L-Arabinose'} g6p_c
# Enzyme cost total is:0.06533641298131466
# 0.128
# demand: DM_f6p_c
# {'R2406': 'L-Arabinose'} f6p_c
# Enzyme cost total is:0.06398355111510728
# 0.128
# demand: DM_g3p_c
# {'R2406': 'L-Arabinose'} g3p_c
# Enzyme cost total is:0.06997209650176657
# 0.128
# demand: DM_3pg_c
# {'R2406': 'L-Arabinose'} 3pg_c
# Enzyme cost total is:0.05768647327048143
# 0.128
# demand: DM_pep_c
# {'R2406': 'L-Arabinose'} pep_c
# Enzyme cost total is:0.06056770304458854
# 0.128
# demand: DM_pyr_c
# {'R2406': 'L-Arabinose'} pyr_c
# Enzyme cost total is:0.039810280966677616
# 0.128
# demand: DM_accoa_m
# {'R2406': 'L-Arabinose'} accoa_m
# Enzyme cost total is:0.12800000000000009
# 0.128
# demand: DM_oaa_m
# {'R2406': 'L-Arabinose'} oaa_m
# Enzyme cost total is:0.04977627819584221
# 0.128
# demand: DM_akg_m
# {'R2406': 'L-Arabinose'} akg_m
# Enzyme cost total is:0.1279999999999999
# 0.128
# demand: DM_succ_m
# {'R2406': 'L-Arabinose'} succ_m
# Enzyme cost total is:0.057276340977471016
# 0.128
# demand: DM_e4p_c
# {'R2406': 'L-Arabinose'} e4p_c
# Enzyme cost total is:0.06635889218305165
# 0.128
# demand: DM_R5P_c
# {'R2406': 'L-Arabinose'} R5P_c
# Enzyme cost total is:0.05885075834693939

# %%
min_enzyme
# Out:
#                 G6P_C     F6P_C     G3P_C     3PG_C     PEP_C     PYR_C  \
# D-Glucose    0.026767  0.025565  0.037795  0.019647  0.022529  0.007916
# Cellobiose   0.022280  0.021770  0.034187  0.016570  0.019451  0.008276
# D-Galactose  0.036686  0.036819  0.049049  0.030901  0.033783  0.019170
# D-Xylose     0.045565  0.044193  0.053902  0.035754  0.038635  0.024023
# L-Arabinose  0.065336  0.063984  0.069972  0.057686  0.060568  0.039810
#
#              ACCOA_M     OAA_M     AKG_M    SUCC_M     E4P_C     R5P_C
# D-Glucose      0.128  0.023326  0.105866  0.027127  0.041487  0.035767
# Cellobiose     0.128  0.023516  0.100826  0.027002  0.037935  0.032128
# D-Galactose    0.128  0.033647  0.117120  0.038336  0.052741  0.047021
# D-Xylose       0.128  0.036846  0.121972  0.042531  0.051955  0.039953
# L-Arabinose    0.128  0.049776  0.128000  0.057276  0.066359  0.058851

# %%
min_enzyme.to_csv('酶量使用.csv')

# %%
efficiency
# Out:
#                   G6P_C       F6P_C       G3P_C       3PG_C       PEP_C  \
# D-Glucose     87.729492   91.853300  120.801940  254.486886  221.940045
# Cellobiose   107.004270  109.508783  135.588403  301.756049  257.057446
# D-Galactose   64.008880   63.777689   93.084706  161.805264  148.005308
# D-Xylose      51.323366   52.916493   84.704564  139.844729  129.415768
# L-Arabinose   35.298319   36.044663   64.758032   86.675431   82.552247
#
#                   PYR_C   ACCOA_M       OAA_M      AKG_M      SUCC_M  \
# D-Glucose    631.635143  3.753914  160.767756  28.337798  138.239520
# Cellobiose   604.187493  3.861204  159.467036  29.754287  138.879221
# D-Galactose  260.825187  3.554754  111.450576  25.614833   97.818311
# D-Xylose     208.137995  3.455045  101.775584  24.595762   88.172012
# L-Arabinose  125.595708  3.113460   75.337103  22.753999   65.472071
#
#                  E4P_C      R5P_C
# D-Glucose    83.703453  78.334793
# Cellobiose   92.936583  88.537538
# D-Galactose  65.842703  59.586319
# D-Xylose     66.838525  70.127922
# L-Arabinose  51.866610  47.026051

# %%
efficiency.to_csv('层级利用.csv')

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# 读取 CSV 文件到 DataFrame
df = pd.read_csv('层级利用.csv')
df.set_index('Unnamed: 0', inplace=True)

# 将 DataFrame 中的值转换为浮点数
df = df.astype(float)

# 设置样式
sns.set(style="whitegrid", font='Times New Roman')

# 创建热图
plt.figure(figsize=(8, 4))
# 修改 annot_kws 参数，设置字体大小
sns.heatmap(df, annot=True, cmap='YlGnBu', fmt='.1f', linewidths=.5)

# 设置标题和轴标签
# plt.title('Substrate Utilization', fontdict={'fontsize': 16, 'family': 'Times New Roman'})
plt.xlabel('Precursors', fontdict={'fontsize': 14, 'family': 'Times New Roman'})
plt.ylabel('Substrates', fontdict={'fontsize': 14, 'family': 'Times New Roman'})

# 保存图像
plt.savefig('analysis/层级利用结果20231月17.png', bbox_inches='tight', dpi=300)
plt.show()
