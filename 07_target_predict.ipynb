# %% [markdown]
# # Import related functions

# %%
import sys
sys.path.append(r'./script/')
from ECMpy_function import *

# %% [markdown]
# # Input and output files

# %%
json_output_file = './model/ecMTM.json'
json_model_file=json_output_file
reaction_kcat_MW = pd.read_csv('./get_reaction_kcat/kcat/reaction_change_by_C13_TurNup24_1.csv',index_col=0)
json_model_file=json_output_file

# %% [markdown]
# # Enzyme-constrained model predicts target genes

# %% [markdown]
# ## Glucose

# %% [markdown]
# # 产量为目标biomass10%

# %%
name_lst=['mal__L','fum','etoh','succ']#产品名称，苹果酸、富马酸、乙醇、琥珀酸、乳酸
for name in name_lst:
    enz_model=get_enzyme_constraint_model(json_model_file)
    product = enz_model.metabolites.get_by_id(name+'_e')
    demand = enz_model.add_boundary(product, type='demand')  # add demand reaction as the objective 增加需求反应作为目标
    enz_model.objective =demand
    substrate='R2399_reverse'#底物growth_model.reactions.get_by_id("R1975_num2").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num1").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num2").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num3").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num4").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num5").bounds=(0,0)
    enz_model.reactions.get_by_id(substrate).bounds=(0,3.0676)#底物
    enz_model.reactions.get_by_id('R2399').bounds=(0,0)
    
    enz_model.reactions.get_by_id('Biomass').bounds=(0.2573,0.2573)#%10生物量
    
    enz_model_solution = cobra.flux_analysis.pfba(enz_model)
    #将or关系反应通量为0的反应永远关闭
    reac=dict(enz_model_solution.fluxes[abs(enz_model_solution.fluxes) > 1e-10])
    reactionlist=[]#反应列表信息
    for i in reac:
        # print( enz_model.reactions.get_by_id(i).gene_reaction_rule,":",enz_model.reactions.get_by_id(i), ":",reac[i])
        # print(i)
        # genelist.append(enz_model.reactions.get_by_id(i).gene_reaction_rule)
        # ID=i
        reID=str(enz_model.reactions.get_by_id(i))
        reID=str(enz_model.reactions.get_by_id(i)).split(':')[0]
        # if ID=='R38_num':
        #     print(ID)
        #     print(reac[i])
        reID= reID.split('_')[0]
        reactionlist.append(reID)#获得通量不为0的反应
    model_pfba_solution = cobra.flux_analysis.pfba(enz_model)
        #将or关系反应通量为0的反应，永远关闭并且只关闭在高生长时有通量的or反应
    for index in reactionlist:
        for i in enz_model.reactions:
            if '_num'in i.id and index in i.id:
                if float(model_pfba_solution.fluxes[i.id])==0:
                    enz_model.reactions.get_by_id(i.id).bounds=(0,0)

    
#     enz_model.reactions.get_by_id('Biomass').bounds=(0.2573,0.2573)#%10生物量

    enz_model.reactions.get_by_id('Biomass').bounds=(0.02573,0.02573)#%10生物量
    

    fluxes_outfile = './analysis/eciDL1450_'+name+'_biomass10%'+'.csv'#每个产物的通量信息表
#     fluxes_outfile = './analysis/eciDL1450_'+name+'biomass100%'+'.csv'
    enz_model.reactions.get_by_id('Biomass').bounds=(0.02573,0.02573)#%10生物量
#     enz_model_pfba_solution=get_min_enzyme_cost(enz_model,reaction_kcat_MW)
    enz_model_pfba_solution = cobra.flux_analysis.pfba(enz_model)

    enz_model_pfba_solution = get_fluxes_detail_in_model(enz_model,enz_model_pfba_solution,fluxes_outfile,json_model_file)
# Out:
# 0.128
# Enzyme cost total is:0.04925362433302409
# 0.128
# Enzyme cost total is:0.06041065892102907
# 0.128
# Enzyme cost total is:0.017582311999569143
# 0.128
# Enzyme cost total is:0.06172841540288932

# %% [markdown]
# # 产量为目标biomass100%

# %%
name_lst=['mal__L','fum','etoh','succ']#产品名称，苹果酸、富马酸、乙醇、琥珀酸、乳酸
for name in name_lst:
    enz_model=get_enzyme_constraint_model(json_model_file)
    product = enz_model.metabolites.get_by_id(name+'_e')
    demand = enz_model.add_boundary(product, type='demand')  # add demand reaction as the objective 增加需求反应作为目标
    enz_model.objective = demand
    substrate='R2399_reverse'#底物growth_model.reactions.get_by_id("R1975_num2").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num1").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num2").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num3").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num4").bounds=(0,0)
    enz_model.reactions.get_by_id("R1975_num5").bounds=(0,0)
    enz_model.reactions.get_by_id(substrate).bounds=(0,3.0676)#底物
    enz_model.reactions.get_by_id('Biomass').bounds=(0.2573,0.2573)#%10生物量
    enz_model_solution = cobra.flux_analysis.pfba(enz_model)
    reac=dict(enz_model_solution.fluxes[abs(enz_model_solution.fluxes) > 1e-10])
    reactionlist=[]#反应列表信息
    for i in reac:
        # print( enz_model.reactions.get_by_id(i).gene_reaction_rule,":",enz_model.reactions.get_by_id(i), ":",reac[i])
        # print(i)
        # genelist.append(enz_model.reactions.get_by_id(i).gene_reaction_rule)
        # ID=i
        reID=str(enz_model.reactions.get_by_id(i))
        reID=str(enz_model.reactions.get_by_id(i)).split(':')[0]
        # if ID=='R38_num':
        #     print(ID)
        #     print(reac[i])
        reID= reID.split('_')[0]
        reactionlist.append(reID)#获得通量不为0的反应
    model_pfba_solution = cobra.flux_analysis.pfba(enz_model)
        #将or关系反应通量为0的反应，永远关闭并且只关闭在高生长时有通量的or反应
    for index in reactionlist:
        for i in enz_model.reactions:
            if '_num'in i.id and index in i.id:
                if float(model_pfba_solution.fluxes[i.id])==0:
                    enz_model.reactions.get_by_id(i.id).bounds=(0,0)

#     fluxes_outfile = './analysis/eciDL1450_'+name+'_biomass10%'+'.csv'#每个产物的通量信息表
    fluxes_outfile = './analysis/eciDL1450_'+name+'biomass100%'+'.csv'

    enz_model_pfba_solution = cobra.flux_analysis.pfba(enz_model)
    enz_model_pfba_solution = get_fluxes_detail_in_model(enz_model,enz_model_pfba_solution,fluxes_outfile,json_model_file)
# Out:
# 0.128
# Enzyme cost total is:0.12800000000000017
# 0.128
# Enzyme cost total is:0.12800000000000006
# 0.128
# Enzyme cost total is:0.12800000000000014
# 0.128
# Enzyme cost total is:0.12800000000000003

# %% [markdown]
# ## Introduction of heterogenous pathways

# %% [markdown]
# # Top15 of enzyme cost

# %%
#苹果酸
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_mal__L_biomass10%.csv')
enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage1.head(15)
# Out:
#        Unnamed: 0    fluxes  \
# 0            R107  2.761032
# 1    R105_reverse  3.918197
# 2           R1963  2.943801
# 3            R351  1.001322
# 4             R40  4.996164
# 5             R61  1.008048
# 6           R2158  0.397717
# 7      R2074_num4  3.447814
# 8      R2250_num6  3.067600
# 9             R46  0.526618
# 10  R1037_reverse  3.949205
# 11            R60  3.025194
# 12          R2308  2.200706
# 13   R110_reverse  0.423158
# 14          R2157  0.686971
#
#                                                   equ          ec-code  \
# 0   atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...          6.4.1.1
# 1           h_c + nadh_c + oaa_c --> mal__L_c + nad_c              NaN
# 2            h_c + nadph_c + o2_c --> h2o2_c + nadp_c              NaN
# 3                 e4p_c + xu5p__D_c --> f6p_c + g3p_c          2.2.1.1
# 4                             2pg_c --> h2o_c + pep_c         4.2.1.11
# 5                 R5P_c + xu5p__D_c --> g3p_c + s7p_c  2.2.1.1,2.2.1.3
# 6   4.0 He_m + 2.0 ficytC_m + qh2_m --> 2.0 FERO_m...              NaN
# 7              h2o2_c + meoh_c --> fald_c + 2.0 h2o_c         1.11.1.6
# 8                               glc__D_e --> glc__D_c              NaN
# 9   coa_m + nad_m + pyr_m --> accoa_m + co2_m + h_...          1.2.4.1
# 10           fald_c + h_c + nadh_c --> meoh_c + nad_c              NaN
# 11                    6pgl_c + h2o_c --> 6pgc_c + h_c         3.1.1.31
# 12                                    pyr_c --> pyr_m              NaN
# 13                         fum_c + h2o_c --> mal__L_c              NaN
# 14  4.0 He_m + h_m + nadh_m + q_m --> 4.0 He_i + n...          1.6.5.9
#
#         kcat_MW         E
# 0    493.871800  0.005591
# 1    932.974738  0.004200
# 2    789.385684  0.003729
# 3    317.127316  0.003157
# 4   1742.654517  0.002867
# 5    390.600732  0.002581
# 6    169.705002  0.002344
# 7   1883.874388  0.001830
# 8   1939.388514  0.001582
# 9    334.549623  0.001574
# 10  2531.609393  0.001560
# 11  2017.119611  0.001500
# 12  1736.623927  0.001267
# 13   336.830555  0.001256
# 14   574.185918  0.001196

# %%
#苹果酸
# 计算需要增强的反应
#苹果酸
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_mal__L_biomass10%.csv')
enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage2=pd.read_csv('./analysis/eciDL1450_mal__Lbiomass100%.csv')
enzyme_usage2=enzyme_usage2.sort_values(['E'],ascending=False).reset_index(drop=True)
df=pd.DataFrame()

list=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage1.loc[index,'E']/float(enzyme_usage2[enzyme_usage2.iloc[:,0]==enzyme_usage1.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage1.loc[index, 'changeradio'] = changeradio
        list.append(enzyme_usage1.loc[index])
df=pd.DataFrame(list)
df.to_csv('./analysis/mal__LEnhance_TurNup.csv')
df1=pd.DataFrame()
list1=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage2.loc[index,'E']/float(enzyme_usage1[enzyme_usage1.iloc[:,0]==enzyme_usage2.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage2.loc[index, 'changeradio'] = changeradio
        list1.append(enzyme_usage2.loc[index])
df1=pd.DataFrame(list1)
df1.to_csv('./analysis/mal__LWeakness_TurNup.csv')

# enzyme_usage=pd.read_csv('./analysis/eciDL1450_mal__L_biomass10%.csv')
# enzyme_usage.sort_values(['E'],ascending=False,inplace=True)
enzyme_usage1.head(15)
# Out:
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning:
#
# invalid value encountered in double_scalars
#        Unnamed: 0    fluxes  \
# 0            R107  2.761032
# 1    R105_reverse  3.918197
# 2           R1963  2.943801
# 3            R351  1.001322
# 4             R40  4.996164
# 5             R61  1.008048
# 6           R2158  0.397717
# 7      R2074_num4  3.447814
# 8      R2250_num6  3.067600
# 9             R46  0.526618
# 10  R1037_reverse  3.949205
# 11            R60  3.025194
# 12          R2308  2.200706
# 13   R110_reverse  0.423158
# 14          R2157  0.686971
#
#                                                   equ          ec-code  \
# 0   atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...          6.4.1.1
# 1           h_c + nadh_c + oaa_c --> mal__L_c + nad_c              NaN
# 2            h_c + nadph_c + o2_c --> h2o2_c + nadp_c              NaN
# 3                 e4p_c + xu5p__D_c --> f6p_c + g3p_c          2.2.1.1
# 4                             2pg_c --> h2o_c + pep_c         4.2.1.11
# 5                 R5P_c + xu5p__D_c --> g3p_c + s7p_c  2.2.1.1,2.2.1.3
# 6   4.0 He_m + 2.0 ficytC_m + qh2_m --> 2.0 FERO_m...              NaN
# 7              h2o2_c + meoh_c --> fald_c + 2.0 h2o_c         1.11.1.6
# 8                               glc__D_e --> glc__D_c              NaN
# 9   coa_m + nad_m + pyr_m --> accoa_m + co2_m + h_...          1.2.4.1
# 10           fald_c + h_c + nadh_c --> meoh_c + nad_c              NaN
# 11                    6pgl_c + h2o_c --> 6pgc_c + h_c         3.1.1.31
# 12                                    pyr_c --> pyr_m              NaN
# 13                         fum_c + h2o_c --> mal__L_c              NaN
# 14  4.0 He_m + h_m + nadh_m + q_m --> 4.0 He_i + n...          1.6.5.9
#
#         kcat_MW         E  changeradio
# 0    493.871800  0.005591     2.724544
# 1    932.974738  0.004200          NaN
# 2    789.385684  0.003729          inf
# 3    317.127316  0.003157     7.488625
# 4   1742.654517  0.002867          NaN
# 5    390.600732  0.002581     5.015897
# 6    169.705002  0.002344          NaN
# 7   1883.874388  0.001830          inf
# 8   1939.388514  0.001582    53.971343
# 9    334.549623  0.001574          NaN
# 10  2531.609393  0.001560          inf
# 11  2017.119611  0.001500     4.931756
# 12  1736.623927  0.001267          NaN
# 13   336.830555  0.001256          inf
# 14   574.185918  0.001196          NaN

# %%
#富马酸
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_fum_biomass10%.csv')

enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage1.head(15)
# Out:
#        Unnamed: 0    fluxes  \
# 0            R110  3.918197
# 1            R107  2.761032
# 2    R105_reverse  3.918197
# 3           R1963  2.943801
# 4            R351  1.001322
# 5             R40  4.996164
# 6             R61  1.008048
# 7           R2158  0.397717
# 8   R2269_reverse  4.341355
# 9      R2074_num4  3.447814
# 10     R2250_num6  3.067600
# 11            R46  0.526618
# 12  R1037_reverse  3.949205
# 13            R60  3.025194
# 14          R2308  2.200706
#
#                                                   equ          ec-code  \
# 0                          mal__L_c --> fum_c + h2o_c          4.2.1.2
# 1   atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...          6.4.1.1
# 2           h_c + nadh_c + oaa_c --> mal__L_c + nad_c              NaN
# 3            h_c + nadph_c + o2_c --> h2o2_c + nadp_c              NaN
# 4                 e4p_c + xu5p__D_c --> f6p_c + g3p_c          2.2.1.1
# 5                             2pg_c --> h2o_c + pep_c         4.2.1.11
# 6                 R5P_c + xu5p__D_c --> g3p_c + s7p_c  2.2.1.1,2.2.1.3
# 7   4.0 He_m + 2.0 ficytC_m + qh2_m --> 2.0 FERO_m...              NaN
# 8                                     fum_c --> fum_e              NaN
# 9              h2o2_c + meoh_c --> fald_c + 2.0 h2o_c         1.11.1.6
# 10                              glc__D_e --> glc__D_c              NaN
# 11  coa_m + nad_m + pyr_m --> accoa_m + co2_m + h_...          1.2.4.1
# 12           fald_c + h_c + nadh_c --> meoh_c + nad_c              NaN
# 13                    6pgl_c + h2o_c --> 6pgc_c + h_c         3.1.1.31
# 14                                    pyr_c --> pyr_m              NaN
#
#         kcat_MW         E
# 0    347.008310  0.011291
# 1    493.871800  0.005591
# 2    932.974738  0.004200
# 3    789.385684  0.003729
# 4    317.127316  0.003157
# 5   1742.654517  0.002867
# 6    390.600732  0.002581
# 7    169.705002  0.002344
# 8   2313.412042  0.001877
# 9   1883.874388  0.001830
# 10  1939.388514  0.001582
# 11   334.549623  0.001574
# 12  2531.609393  0.001560
# 13  2017.119611  0.001500
# 14  1736.623927  0.001267

# %%
#富马酸
# 计算需要增强的反应
#苹果酸
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_fum_biomass10%.csv')
enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage2=pd.read_csv('./analysis/eciDL1450_fumbiomass100%.csv')
enzyme_usage2=enzyme_usage2.sort_values(['E'],ascending=False).reset_index(drop=True)
df=pd.DataFrame()

list=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage1.loc[index,'E']/float(enzyme_usage2[enzyme_usage2.iloc[:,0]==enzyme_usage1.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage1.loc[index, 'changeradio'] = changeradio
        list.append(enzyme_usage1.loc[index])
df=pd.DataFrame(list)
df.to_csv('./analysis/fumEnhance_TurNup.csv')
df1=pd.DataFrame()
list1=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage2.loc[index,'E']/float(enzyme_usage1[enzyme_usage1.iloc[:,0]==enzyme_usage2.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage2.loc[index, 'changeradio'] = changeradio
        list1.append(enzyme_usage2.loc[index])
df1=pd.DataFrame(list1)
df1.to_csv('./analysis/fumWeakness_TurNup.csv')

# enzyme_usage=pd.read_csv('./analysis/eciDL1450_fum10%.csv')
# enzyme_usage.sort_values(['E'],ascending=False,inplace=True)
enzyme_usage1.head(15)
# Out:
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:12: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:21: RuntimeWarning:
#
# invalid value encountered in double_scalars
#        Unnamed: 0    fluxes  \
# 0           R1458  0.052133
# 1           R2157  0.005759
# 2   R1037_reverse  1.619475
# 3            R107  2.708899
# 4    R687_reverse  0.468861
# 5             R61  1.008048
# 6            R351  1.001322
# 7      R2250_num6  3.067600
# 8             R50  4.996164
# 9           R1036  1.997356
# 10            R60  3.025194
# 11          R1710  0.001289
# 12            R46  0.474485
# 13     R1044_num1  1.997356
# 14          R1608  0.000900
#
#                                                   equ            ec-code  \
# 0            lac__L_c + o2_c --> ac_c + co2_c + h2o_c          1.13.12.4
# 1   4.0 He_m + h_m + nadh_m + q_m --> 4.0 He_i + n...            1.6.5.9
# 2            fald_c + h_c + nadh_c --> meoh_c + nad_c                NaN
# 3   atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...            6.4.1.1
# 4       h_m + nadph_m + td2coa_m --> nadp_m + tdcoa_m                NaN
# 5                 R5P_c + xu5p__D_c --> g3p_c + s7p_c    2.2.1.1,2.2.1.3
# 6                 e4p_c + xu5p__D_c --> f6p_c + g3p_c            2.2.1.1
# 7                               glc__D_e --> glc__D_c                NaN
# 8     g3p_c + nad_c + pi_c --> 13dpg_c + h_c + nadh_c  1.2.1.12,1.2.1.59
# 9             atp_c + f6p_c --> adp_c + fdp_B_c + h_c           2.7.1.11
# 10                    6pgl_c + h2o_c --> 6pgc_c + h_c           3.1.1.31
# 11                   h2o_c + mnl1p_c --> mnl_c + pi_c           3.1.3.22
# 12  coa_m + nad_m + pyr_m --> accoa_m + co2_m + h_...            1.2.4.1
# 13                         fdp_B_c --> dhap_c + g3p_c           4.1.2.13
# 14      amet_c + zymst_c --> ahcys_c + fecost_c + h_c           2.1.1.41
#
#         kcat_MW         E  changeradio
# 0      1.157031  0.045057          inf
# 1      0.177998  0.032353     6.980417
# 2    151.888498  0.010662          inf
# 3    461.607379  0.005868          inf
# 4     95.563765  0.004906          inf
# 5    403.570784  0.002498     7.627789
# 6    403.570784  0.002481    15.429533
# 7   1303.888867  0.002353   240.038102
# 8   2177.313727  0.002295          NaN
# 9   1127.881316  0.001771          NaN
# 10  1827.812785  0.001655     7.433581
# 11     0.847249  0.001521          NaN
# 12   334.549623  0.001418          NaN
# 13  1523.895284  0.001311          NaN
# 14     0.751296  0.001198          NaN

# %%
#乙醇
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_etoh_biomass10%.csv')
enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage1.head(15)
# Out:
#           Unnamed: 0    fluxes  \
# 0                 R9  5.715059
# 1                R40  6.004212
# 2         R2251_num6  2.051484
# 3               R107  0.271623
# 4         R2249_num6  1.010432
# 5       R110_reverse  0.170323
# 6           R36_num2  2.694409
# 7                R51  6.004212
# 8         R1044_num1  3.005404
# 9   R10_reverse_num8  5.771227
# 10               R46  0.114757
# 11             R1974  0.025730
# 12             R1036  3.005404
# 13               R50  6.004212
# 14              R145  0.180586
#
#                                                   equ            ec-code  \
# 0                     h_c + pyr_c --> acald_c + co2_c            4.1.1.1
# 1                             2pg_c --> h2o_c + pep_c           4.2.1.11
# 2                                 BDGLC_e --> BDGLC_c                NaN
# 3   atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...            6.4.1.1
# 4                  glc__aD_e + h_e --> Glc_aD_c + h_c                NaN
# 5                          fum_c + h2o_c --> mal__L_c                NaN
# 6               adp_c + h_c + pep_c --> atp_c + pyr_c           2.7.1.40
# 7                   13dpg_c + adp_c --> 3pg_c + atp_c            2.7.2.3
# 8                          fdp_B_c --> dhap_c + g3p_c           4.1.2.13
# 9           acald_c + h_c + nadh_c --> etoh_c + nad_c                NaN
# 10  coa_m + nad_m + pyr_m --> accoa_m + co2_m + h_...            1.2.4.1
# 11  0.0097602 amp_c + 0.13641 atp_c + 0.016694 cmp...                NaN
# 12            atp_c + f6p_c --> adp_c + fdp_B_c + h_c           2.7.1.11
# 13    g3p_c + nad_c + pi_c --> 13dpg_c + h_c + nadh_c  1.2.1.12,1.2.1.59
# 14  akg_c + gln__L_c + h_c + nadh_c --> 2.0 glu__L...           1.4.1.14
#
#          kcat_MW         E
# 0    1200.440609  0.004761
# 1    1742.654517  0.003445
# 2    1939.388514  0.001058
# 3     493.871800  0.000550
# 4    1939.388514  0.000521
# 5     336.830555  0.000506
# 6    6213.023429  0.000434
# 7   14639.821700  0.000410
# 8    7408.739714  0.000406
# 9   15075.254510  0.000383
# 10    334.549623  0.000343
# 11     86.711084  0.000297
# 12  10441.180316  0.000288
# 13  24759.805924  0.000242
# 14    897.497568  0.000201

# %%
#乙醇
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_etoh_biomass10%.csv')
# enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage2=pd.read_csv('./analysis/eciDL1450_etohbiomass100%.csv')
# enzyme_usage2=enzyme_usage2.sort_values(['E'],ascending=False).reset_index(drop=True)
df=pd.DataFrame()

list=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage1.loc[index,'E']/float(enzyme_usage2[enzyme_usage2.iloc[:,0]==enzyme_usage1.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage1.loc[index, 'changeradio'] = changeradio
        list.append(enzyme_usage1.loc[index])
df=pd.DataFrame(list)
df.to_csv('./analysis/etohEnhance_TurNup1_14.csv')
df1=pd.DataFrame()
list1=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage2.loc[index,'E']/float(enzyme_usage1[enzyme_usage1.iloc[:,0]==enzyme_usage2.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage1.loc[index, 'changeradio'] = changeradio
        list1.append(enzyme_usage1.loc[index])
df1=pd.DataFrame(list1)
df1.to_csv('./analysis/etohWeakness_TurNup1_14.csv')

# enzyme_usage=pd.read_csv('./analysis/eciDL1450_etoh10%.csv')
# enzyme_usage.sort_values(['E'],ascending=False,inplace=True)
enzyme_usage1.head(15)
# Out:
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#    Unnamed: 0    fluxes                                                equ  \
# 0          R1  3.067600         glc__D_e --> 0.67 BDGLC_e + 0.33 glc__aD_e
# 1          R2  0.000000          glc__D_c --> 0.67 BDGLC_c + 0.33 Glc_aD_c
# 2          R3  0.000000                               Glc_aD_c --> BDGLC_c
# 3          R4  0.000000                             arab__L_c --> BLARAB_c
# 4          R5  0.000000                                  fru_B_c --> fru_c
# 5     R6_num1  2.051484          BDGLC_c + atp_c --> adp_c + g6p_B_c + h_c
# 6          R7  2.051484                                  g6p_B_c --> f6p_c
# 7          R8  0.000000                             cit_m --> ac_m + oaa_m
# 8          R9  5.766755                    h_c + pyr_c --> acald_c + co2_c
# 9    R10_num1  0.000000          etoh_c + nad_c --> acald_c + h_c + nadh_c
# 10   R11_num1  0.000000        etoh_c + nadp_c --> acald_c + h_c + nadph_c
# 11   R12_num1  0.000000          etoh_m + nad_m --> acald_m + h_m + nadh_m
# 12        R13  0.000000               h_m + nadh_m + q_m --> nad_m + qh2_m
# 13        R14  0.000000               h_c + nadh_c + q_m --> nad_c + qh2_m
# 14   R15_num1  0.000000  2.0 ficytC_m + nadph_c --> 2.0 FERO_m + h_c + ...
#
#              ec-code        kcat_MW         E  changeradio
# 0                NaN            NaN       NaN          NaN
# 1                NaN            NaN       NaN          NaN
# 2            5.1.3.3  625066.591111  0.000000          NaN
# 3            5.1.3.3  625066.591111  0.000000          NaN
# 4            5.1.3.3  625066.591111  0.000000          NaN
# 5    2.7.1.1,2.7.1.2    3328.716016  0.000616          NaN
# 6            5.3.1.9  178726.601902  0.000011          NaN
# 7            4.1.3.6            NaN       NaN          NaN
# 8            4.1.1.1    2620.070691  0.002201     6.045869
# 9   1.1.1.1,1.1.1.71   35847.749665  0.000000          NaN
# 10  1.1.1.2,1.1.1.71  146385.645055  0.000000          NaN
# 11  1.1.1.1,1.1.1.71   35996.911166  0.000000          NaN
# 12           1.6.5.9       0.782496  0.000000          NaN
# 13           1.6.5.9       0.782496  0.000000          NaN
# 14           1.6.2.4    2310.009387  0.000000          NaN

# %%
#琥珀酸
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_succ_biomass10%.csv')
enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage1.head(15)
# Out:
#             Unnamed: 0    fluxes  \
# 0             R43_num1  2.416926
# 1                R2158  0.792803
# 2             R36_num1  4.541040
# 3                 R107  1.802576
# 4           R2250_num1  3.067600
# 5                  R40  4.996523
# 6                R1036  2.418460
# 7           R1192_num3  0.385316
# 8   R2272_reverse_num1  4.341355
# 9         R105_reverse  1.778287
# 10            R56_num2  1.350499
# 11                R110  0.598853
# 12           R119_num1  3.130704
# 13               R2308  2.722059
# 14               R2159  0.792803
#
#                                                   equ             ec-code  \
# 0                                    dhap_c --> g3p_c             5.3.1.1
# 1   4.0 He_m + 2.0 ficytC_m + qh2_m --> 2.0 FERO_m...                 NaN
# 2               adp_c + h_c + pep_c --> atp_c + pyr_c            2.7.1.40
# 3   atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...             6.4.1.1
# 4                               glc__D_e --> glc__D_c                 NaN
# 5                             2pg_c --> h2o_c + pep_c            4.2.1.11
# 6             atp_c + f6p_c --> adp_c + fdp_B_c + h_c            2.7.1.11
# 7                        3dhsk_c --> 34dhbz_c + h2o_c                 NaN
# 8                       h_c + succ_c --> h_e + succ_e                 NaN
# 9           h_c + nadh_c + oaa_c --> mal__L_c + nad_c                 NaN
# 10    6pgc_c + nadp_c --> co2_c + nadph_c + ru5p__D_c  1.1.1.44,1.1.1.351
# 11                         mal__L_c --> fum_c + h2o_c             4.2.1.2
# 12            fum_c + h_c + nadh_c --> nad_c + succ_c             1.3.1.6
# 13                                    pyr_c --> pyr_m                 NaN
# 14  2.0 FERO_m + 4.0 He_m + 2.0 h_m + 0.5 o2_m -->...     1.7.2.1,7.1.1.9
#
#         kcat_MW         E
# 0    283.714043  0.008519
# 1    169.705002  0.004672
# 2   1272.163396  0.003570
# 3    556.812006  0.003237
# 4    990.364250  0.003097
# 5   1905.531727  0.002622
# 6   1044.118032  0.002316
# 7    199.425628  0.001932
# 8   2313.412042  0.001877
# 9    990.208832  0.001796
# 10   777.412342  0.001737
# 11   347.008310  0.001726
# 12  1888.831496  0.001657
# 13  1736.623927  0.001567
# 14   516.961503  0.001534

# %%
#琥珀酸
enzyme_usage1=pd.read_csv('./analysis/eciDL1450_succ_biomass10%.csv')
enzyme_usage1=enzyme_usage1.sort_values(['E'],ascending=False).reset_index(drop=True)
enzyme_usage2=pd.read_csv('./analysis/eciDL1450_succbiomass100%.csv')
enzyme_usage2=enzyme_usage2.sort_values(['E'],ascending=False).reset_index(drop=True)
df=pd.DataFrame()

list=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage1.loc[index,'E']/float(enzyme_usage2[enzyme_usage2.iloc[:,0]==enzyme_usage1.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage1.loc[index, 'changeradio'] = changeradio
        list.append(enzyme_usage1.loc[index])
df=pd.DataFrame(list)
df.to_csv('./analysis/succEnhance_TurNup.csv')
df1=pd.DataFrame()
list1=[]
for index in range(len(enzyme_usage1)):
    changeradio=enzyme_usage2.loc[index,'E']/float(enzyme_usage1[enzyme_usage1.iloc[:,0]==enzyme_usage2.iloc[index,0]]['E'])
    if changeradio>=1.5:
        enzyme_usage2.loc[index, 'changeradio'] = changeradio
        list1.append(enzyme_usage2.loc[index])
df1=pd.DataFrame(list1)
df1.to_csv('./analysis/succWeakness_TurNup.csv')

# enzyme_usage=pd.read_csv('./analysis/eciDL1450_succ10%.csv')
# enzyme_usage.sort_values(['E'],ascending=False,inplace=True)
enzyme_usage1.head(15)
# Out:
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning:
#
# invalid value encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# E:\Anaconda\envs\cobra\lib\site-packages\ipykernel_launcher.py:19: RuntimeWarning:
#
# invalid value encountered in double_scalars
#       Unnamed: 0    fluxes                                                equ  \
# 0            R46  2.879945  coa_m + nad_m + pyr_m --> accoa_m + co2_m + h_...
# 1   R111_reverse  1.574445                     fum_m + qh2_m --> q_m + succ_m
# 2           R107  2.829501  atp_c + co2_c + h2o_c + pyr_c --> adp_c + 2.0 ...
# 3            R14  2.903129               h_c + nadh_c + q_m --> nad_c + qh2_m
# 4          R2157  1.817834  4.0 He_m + h_m + nadh_m + q_m --> 4.0 He_i + n...
# 5            R40  5.990997                            2pg_c --> h2o_c + pep_c
# 6          R1036  2.992189            atp_c + f6p_c --> adp_c + fdp_B_c + h_c
# 7       R43_num2  2.990654                                   dhap_c --> g3p_c
# 8          R2308  4.485539                                    pyr_c --> pyr_m
# 9      R923_num1  2.765188                          icit_x --> glx_x + succ_x
# 10  R105_reverse  1.574445          h_c + nadh_c + oaa_c --> mal__L_c + nad_c
# 11    R2250_num6  3.067600                              glc__D_e --> glc__D_c
# 12          R128  2.765188                 ala__L_c + glx_c --> gly_c + pyr_c
# 13           R17  1.092106              fadh2_m + q_m --> fad_m + h_m + qh2_m
# 14          R408  1.358483         cys__L_c + h2o_c --> h2s_c + nh4_c + pyr_c
#
#              ec-code      kcat_MW         E  changeradio
# 0            1.2.4.1   334.549623  0.008608          NaN
# 1                NaN   212.624700  0.007405          inf
# 2            6.4.1.1   556.812006  0.005082          inf
# 3            1.6.5.9   847.638123  0.003425          inf
# 4            1.6.5.9   574.185918  0.003166          NaN
# 5           4.2.1.11  1905.531727  0.003144          NaN
# 6           2.7.1.11  1044.118032  0.002866          NaN
# 7            5.3.1.1  1142.390707  0.002618          NaN
# 8                NaN  1736.623927  0.002583          NaN
# 9            4.1.3.1  1651.481448  0.001674     5.734137
# 10               NaN   990.208832  0.001590          NaN
# 11               NaN  1939.388514  0.001582    53.971343
# 12          2.6.1.44  1828.564508  0.001512     5.734137
# 13           1.5.5.1   736.326363  0.001483          inf
# 14  4.4.1.1,4.4.1.28   944.312839  0.001439          inf
